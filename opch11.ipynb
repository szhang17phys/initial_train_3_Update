# %% [markdown]
# # Related to Comp Graph Module Training
# ### --Created by Shuaixiang (Shu)
# ### --Nov 18, 2023

# %% [markdown]
# ## The following evaluation scripts are used for initial_train_3_Update
# <br />
# <br />
# <br />

# %% [markdown]
# ### Read txt files and general output:

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


#------------------------------------------
opName = 'opch11'
#------------------------------------------

#read data---
posX = []
posY = []
posZ = []
biasValues = []
simuValues = []
emulValues = []
with open('./data/all_xPos.txt'.format(opName), 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        posX.append(float(currentPlace))
with open('./data/all_yPos.txt'.format(opName), 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        posY.append(float(currentPlace))
with open('./data/all_zPos.txt'.format(opName), 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        posZ.append(float(currentPlace))
with open('./data/{}_biasValues.txt'.format(opName), 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        biasValues.append(float(currentPlace))
with open('./data/{}_simuValues.txt'.format(opName), 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        simuValues.append(float(currentPlace))        
with open('./data/{}_emulValues.txt'.format(opName), 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        emulValues.append(float(currentPlace))  
        
        
        
        
        
        
print("Length of posX: ", len(posX))
print("Length of posY: ", len(posY))
print("Length of posZ: ", len(posZ))
print("Length of biasValues: ", len(biasValues))
print("Length of simuValues: ", len(simuValues))
print("Length of emulValues: ", len(emulValues))
#print(posX)
# Out:
# Length of posX:  93190
# Length of posY:  93190
# Length of posZ:  93190
# Length of biasValues:  93190
# Length of simuValues:  93190
# Length of emulValues:  93190

# %% [markdown]
# <br />
# <br />
#
# ### Show the distribution of simu events, emul events as well as bias:

# %%
#Purpose of this block:
#Output the simu(true counts) distributions, and bias distribution---


import matplotlib.pyplot as plt
import numpy as np


print("--------------------")
print("Largest count: ", max(simuValues))
print("Label of max count: ", simuValues.index(max(simuValues)))
maxC_label = simuValues.index(max(simuValues))
print("Emul related to max simu : ", emulValues[maxC_label])
print("Bias related to max count: ", biasValues[maxC_label])
print("Position of max count: (x, y, z) = (", \
      posX[maxC_label], ", ", posY[maxC_label], ", ", posZ[maxC_label], ")")

print("--------------------")
print("Smallest bias: ", min(biasValues))
print("Largest bias : ", max(biasValues))
print("Label of max bias: ", biasValues.index(max(biasValues)))
maxB_label = biasValues.index(max(biasValues))
print("Simu related to max bias: ", simuValues[maxB_label])
print("Emul related to max bias: ", emulValues[maxB_label])
print("Position of max bias: (x, y, z) = (", \
      posX[maxB_label], ", ", posY[maxB_label], ", ", posZ[maxB_label], ")")







#true photon counts=========================================
plt.figure(figsize=(4,3),dpi=300)
plt.hist(simuValues, bins=200, range=(0, 150000), color='blue', alpha=0.7)
plt.xlabel('Photon nums', labelpad=6, fontsize=10)
plt.ylabel('Events', labelpad=6, fontsize=10)
plt.title('True Photon Collections [0, 150000]', fontsize=10)
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid()
plt.show()



#true photon counts (Log(x) function)===========================
plt.figure(figsize=(4,3),dpi=300)
plt.hist(simuValues, bins=200, range=(0, 1000000), color='blue', alpha=0.7)
plt.xlabel('Photon nums', labelpad=6, fontsize=10)
plt.ylabel('Events', labelpad=6, fontsize=10)
plt.title('True Photon Collections [0, 1000000]', fontsize=10)
plt.tick_params(labelsize=7)#set the size of ticks---
plt.xlim(0, 1000000)
plt.yscale('log')
plt.grid()
plt.show()



#Bias distribution=========================================
plt.figure(figsize=(4,3),dpi=300)
plt.hist(biasValues, bins=200, range=(-1, 1), color='blue', alpha=0.7)
plt.xlabel('Bias', labelpad=6, fontsize=10)
plt.ylabel('Events', labelpad=6, fontsize=10)
plt.title('Bias Distribution', fontsize=10)
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid()
plt.show()




#Bias distribution (Log function)===========================
plt.figure(figsize=(4,3),dpi=300)
plt.hist(biasValues, bins=200, range=(-10, 10), color='blue', alpha=0.7)
plt.xlabel('Bias', labelpad=6, fontsize=10)
plt.ylabel('Events', labelpad=6, fontsize=10)
plt.title('Bias Distribution', fontsize=10)
plt.tick_params(labelsize=7)#set the size of ticks---
plt.yscale('log')
plt.grid()
plt.show()
# Out:
# --------------------
# Largest count:  555487.0
# Label of max count:  37909
# Emul related to max simu :  459302.0
# Bias related to max count:  -0.173154
# Position of max count: (x, y, z) = ( 1.83647 ,  -191.305 ,  51.8638 )
# --------------------
# Smallest bias:  -0.860697
# Largest bias :  inf
# Label of max bias:  15437
# Simu related to max bias:  0.0
# Emul related to max bias:  2171.0
# Position of max bias: (x, y, z) = ( 0.800656 ,  -278.229 ,  171.887 )

# %% [markdown]
# <br />
# <br />
#
# ### Detailed analysis on simu values:

# %%
import matplotlib.pyplot as plt
import numpy as np

range10 = 0 # [0, 10]
range50 = 0 # [10, 50]
range100 = 0 #events numbers within [50, 100]
range1000 = 0 #(100, 1000]
range10000 = 0 #(1000, 10000]
range100000 = 0 #(10000, 100000]
range1000000 = 0 #(100000, 1000000]


rows = 2
list10 = [[] for _ in range(rows)]
list50 = [[] for _ in range(rows)]
list100 = [[] for _ in range(rows)]#2D list, list100[0] is label; list100[1] is photon num
list1000 = [[] for _ in range(rows)]
list10000 = [[] for _ in range(rows)]
list100000 = [[] for _ in range(rows)]
list1000000 = [[] for _ in range(rows)]



for i in range(0, len(simuValues)):
    simu = simuValues[i]
    
    if simu <= 10:
        range10 += 1
        list10[0].append(i)
        list10[1].append(simu) 
    if 10 < simu <= 50:
        range50 += 1
        list50[0].append(i)
        list50[1].append(simu)
    if 50 < simu <= 100:
        range100 += 1
        list100[0].append(i)
        list100[1].append(simu)
    elif 100 < simu <= 1000:
        range1000 += 1
        list1000[0].append(i)
        list1000[1].append(simu)
    elif 1000 < simu <= 10000:
        range10000 += 1
        list10000[0].append(i)
        list10000[1].append(simu)
    elif 10000 < simu <= 100000:
        range100000 += 1
        list100000[0].append(i)
        list100000[1].append(simu)
    elif 100000 < simu <= 1000000:
        range1000000 += 1
        list1000000[0].append(i)
        list1000000[1].append(simu)

print("# event in [0, 10]          : ", range10)
print("# event in [10, 50]         : ", range50)
print("# event in [50, 100]        : ", range100)
print("# event in (100, 1000]      : ", range1000)
print("# event in (1000, 10000]    : ", range10000)
print("# event in (10000, 100000]  : ", range100000)
print("# event in (100000, 1000000]: ", range1000000)
totalNum = range10+range50+range100+range1000+range10000+range100000+range1000000
print("Total event nums            : ", totalNum)

print("\nlist length of [0, 10]          : ", len(list10[1]))
print("list length of [10, 50]         : ", len(list50[1]))
print("list length of (50, 100]        : ", len(list100[1]))
print("list length of (100, 1000]      : ", len(list1000[1]))
print("list length of (1000, 10000]    : ", len(list10000[1]))
print("list length of (10000, 100000]  : ", len(list100000[1]))
print("list length of (100000, 1000000]: ", len(list1000000[1]))
print("\nlist1000000[][]: ", list1000000)
print("\n")



#Divide posX, posY and posZ into different (5) groups---
rows = 7
groupX = [[] for _ in range(rows)]
groupY = [[] for _ in range(rows)]
groupZ = [[] for _ in range(rows)]

groupX[0] = [posX[i] for i in list10[0]]
groupX[6] = [posX[i] for i in list50[0]]#6 is corresponding to [10, 50]---
groupX[1] = [posX[i] for i in list100[0]]#corresponding to list100
groupX[2] = [posX[i] for i in list1000[0]]#corresponding to list1000
groupX[3] = [posX[i] for i in list10000[0]]
groupX[4] = [posX[i] for i in list100000[0]]
groupX[5] = [posX[i] for i in list1000000[0]]

groupY[0] = [posY[i] for i in list10[0]]
groupY[6] = [posY[i] for i in list50[0]]
groupY[1] = [posY[i] for i in list100[0]]#corresponding to list100
groupY[2] = [posY[i] for i in list1000[0]]#corresponding to list1000
groupY[3] = [posY[i] for i in list10000[0]]
groupY[4] = [posY[i] for i in list100000[0]]
groupY[5] = [posY[i] for i in list1000000[0]]

groupZ[0] = [posZ[i] for i in list10[0]]
groupZ[6] = [posZ[i] for i in list50[0]]
groupZ[1] = [posZ[i] for i in list100[0]]#corresponding to list100
groupZ[2] = [posZ[i] for i in list1000[0]]#corresponding to list1000
groupZ[3] = [posZ[i] for i in list10000[0]]
groupZ[4] = [posZ[i] for i in list100000[0]]
groupZ[5] = [posZ[i] for i in list1000000[0]]

for i in range(0, rows):
    print("length of groupX[",i,"]: ", len(groupX[i]))
    print("length of groupY[",i,"]: ", len(groupY[i]))
    print("length of groupZ[",i,"]: ", len(groupZ[i]))

    
    
    
    
    

#Start drawing figures====================================================================    
#Set the limts of x, y and z when drawing---
xmin = -400
xmax = 500
ymin = -500
ymax = 500
zmin = -300
zmax = 600

#X-Y plane ploting----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

# Define the field cage frame, start from top right, anti-clockwise---
cageXY_y = [350, -350, -350, 350, 350]
cageXY_x = [340, 340, -340, -340, 340]
plt.plot(cageXY_y, cageXY_x, color="grey", linewidth=0.5, linestyle='--')

#Draw the membrane XArapucas---
plt.plot([418, 418], [272, 332], color="grey", linewidth=0.6, linestyle='-')
plt.plot([-418, -418], [272, 332], color="grey", linewidth=0.6, linestyle='-')
plt.plot([418, 418], [256, 196], color="grey", linewidth=0.6, linestyle='-')
plt.plot([-418, -418], [256, 196], color="grey", linewidth=0.6, linestyle='-')
plt.plot([418, 418], [-177, -237], color="grey", linewidth=0.6, linestyle='-')
plt.plot([-418, -418], [-177, -237], color="grey", linewidth=0.6, linestyle='-')
plt.plot([418, 418], [-253, -313], color="grey", linewidth=0.6, linestyle='-')
plt.plot([-418, -418], [-253, -313], color="grey", linewidth=0.6, linestyle='-')

#Set equal scaling for both axes---
plt.axis('scaled')
plt.xlim(ymin, ymax)#Since in x-y plane, x axis is y of the geometry---
plt.ylim(xmin, xmax)

#auxiliary line, along y(geo) and x axis---
yauxi1 = [ymin, ymax]
yauxi2 = [0, 0]
plt.plot(yauxi1, yauxi2, color="silver", linewidth=0.5, linestyle='--')
xauxi1 = [0, 0]
xauxi2 = [xmin, xmax]
plt.plot(xauxi1, xauxi2, color="silver", linewidth=0.5, linestyle='--')



#Drawing of data points------
plt.scatter(groupY[0], groupX[0], c='lightblue', s=1.0, alpha=1.0, marker='.', label='#$\gamma$ $\in$ [0, 10]')
plt.scatter(groupY[6], groupX[6], c='darkcyan', s=1.0, alpha=1.0, marker='.', label='[10, 50]')
plt.scatter(groupY[1], groupX[1], c='cyan', s=1.0, alpha=1.0, marker='.', label='[50, 100]')
plt.scatter(groupY[2], groupX[2], c='magenta', s=1.0, alpha=1.0, marker='.', label='[100, 1000]')
plt.scatter(groupY[3], groupX[3], c='orange', s=1.0, alpha=1.0, marker='.', label='[1000, 10000]')
plt.scatter(groupY[4], groupX[4], c='lime', s=1.0, alpha=1.0, marker='.', label='[10000, 100000]')
plt.scatter(groupY[5], groupX[5], c='blue', s=1.0, alpha=1.0, marker='.', label='[100000, 1000000]')


plt.xlabel('Y axis [cm]', labelpad=1, fontsize=8)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=8)
plt.title('Events distribution in X-Y plane', fontsize=10)
plt.tick_params(labelsize=7)#set the size of ticks---
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.98), fontsize=6, markerscale=5, ncol=4, prop={'size': 3.5})

#Save the plot as a PNG file
#plt.savefig('simu_XY.png', bbox_inches='tight')
plt.show()    
#---------------------------------------------------------





#X-Z plane ploting----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#Define the field cage frame, start from top right, anti-clockwise---
cageXZ_z = [315, -15, -15, 315, 315]
cageXZ_x = [340, 340, -340, -340, 340]
plt.plot(cageXZ_z, cageXZ_x, color="grey", linewidth=0.5, linestyle='--')

#auxiliary line, along y(geo) and x axis---
yauxi3 = [zmin, zmax]
yauxi4 = [0, 0]
plt.plot(yauxi3, yauxi4, color="silver", linewidth=0.5, linestyle='--')
xauxi3 = [0, 0]
xauxi4 = [xmin, xmax]
plt.plot(xauxi3, xauxi4, color="silver", linewidth=0.5, linestyle='--')

#Draw the membrane XArapucas---
op00z = [180, 120, 120, 180, 180]#From top right, anti-clockwise---
op00x = [332, 332, 272, 272, 332]
plt.plot(op00z, op00x, color="grey", linewidth=0.6, linestyle='-')
op02z = op00z
op02x = [256, 256, 196, 196, 256]
plt.plot(op02z, op02x, color="grey", linewidth=0.6, linestyle='-')
op16z = op00z
op16x = [-177, -177, -237, -237, -177]
plt.plot(op16z, op16x, color="grey", linewidth=0.6, linestyle='-')
op22z = op00z
op22x = [-253, -253, -313, -313, -253]
plt.plot(op22z, op22x, color="grey", linewidth=0.6, linestyle='-')


#Drawing of data points------
plt.scatter(groupZ[0], groupX[0], c='lightblue', s=1.0, alpha=1.0, marker='.', label='#$\gamma$ $\in$ [0, 10]')
plt.scatter(groupZ[6], groupX[6], c='darkcyan', s=1.0, alpha=1.0, marker='.', label='[10, 50]')
plt.scatter(groupZ[1], groupX[1], c='cyan', s=1.0, alpha=1.0, marker='.', label='[50, 100]')
plt.scatter(groupZ[2], groupX[2], c='magenta', s=1.0, alpha=1.0, marker='.', label='[100, 1000]')
plt.scatter(groupZ[3], groupX[3], c='orange', s=1.0, alpha=1.0, marker='.', label='[1000, 10000]')
plt.scatter(groupZ[4], groupX[4], c='lime', s=1.0, alpha=1.0, marker='.', label='[10000, 100000]')
plt.scatter(groupZ[5], groupX[5], c='blue', s=1.0, alpha=1.0, marker='.', label='[100000, 1000000]')

plt.axis('scaled')
plt.xlim(zmin, zmax)
plt.ylim(xmin, xmax)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=8)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)#set the size of ticks---

plt.title('Events distribution in X-Z plane', fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.98), fontsize=6, markerscale=5, ncol=4, prop={'size': 3.2})

#Save the plot as a PNG file
#plt.savefig('simu_XZ.png', bbox_inches='tight')
plt.show()    
#---------------------------------------------------------






#Z-Y plane ploting----------------------------------------
plt.figure(figsize=(4,3),dpi=400)


#Define the field cage frame, start from top right, anti-clockwise---
cageZY_y = [350, -350, -350, 350, 350]
cageZY_z = [315, 315, -15, -15, 315]
plt.plot(cageZY_y, cageZY_z, color="grey", linewidth=0.5, linestyle='--')

#auxiliary line, along y(geo) axis---
yauxi5 = [ymin, ymax]
yauxi6 = [0, 0]
plt.plot(yauxi5, yauxi6, color="silver", linewidth=0.5, linestyle='--')
xauxi5= [0, 0]
xauxi6 = [zmin, 700]
plt.plot(xauxi5, xauxi6, color="silver", linewidth=0.5, linestyle='--')

#Draw the membrane XArapucas---
plt.plot([418, 418], [120, 180], color="grey", linewidth=0.6, linestyle='-')#opch0, 2, 16, 22---
plt.plot([-418, -418], [120, 180], color="grey", linewidth=0.5, linestyle='-')#opch1, 3, 17, 23---
op04y = [236, 176, 176, 236, 236]#From top right, anti-clockwise---
op04z = [288, 288, 228, 228, 288]
plt.plot(op04y, op04z, color="grey", linewidth=0.6, linestyle='-')
op05y = [-101, -161, -161, -101, -101]#From top right, anti-clockwise---
op05z = [288, 288, 228, 228, 288]
plt.plot(op05y, op05z, color="grey", linewidth=0.6, linestyle='-')
op06y = [69, 9, 9, 69, 69]#From top right, anti-clockwise---
op06z = [217, 217, 157, 157, 217]
plt.plot(op06y, op06z, color="grey", linewidth=0.6, linestyle='-')
op07y = [-270, -330, -330, -270, -270]#From top right, anti-clockwise---
op07z = [217, 217, 157, 157, 217]
plt.plot(op07y, op07z, color="grey", linewidth=0.6, linestyle='-')
op08y = op04y#From top right, anti-clockwise---
op08z = [142, 142, 82, 82, 142]
plt.plot(op08y, op08z, color="grey", linewidth=0.6, linestyle='-')
op09y = [-9, -69, -69, -9, -9]#From top right, anti-clockwise---
op09z = [142, 142, 82, 82, 142]
plt.plot(op09y, op09z, color="grey", linewidth=0.6, linestyle='-')
op10y = [161, 101, 101, 161, 161]#From top right, anti-clockwise---
op10z = [71, 71, 11, 11, 71]
plt.plot(op10y, op10z, color="grey", linewidth=0.6, linestyle='-')
op11y = [-176, -236, -236, -176, -176]#From top right, anti-clockwise---
op11z = [71, 71, 11, 11, 71]
plt.plot(op11y, op11z, color="grey", linewidth=0.6, linestyle='-')


#Drawing of data points------
plt.scatter(groupY[0], groupZ[0], c='lightblue', s=1.0, alpha=1.0, marker='.', label='#$\gamma$ $\in$ [0, 10]')
plt.scatter(groupY[6], groupZ[6], c='darkcyan', s=1.0, alpha=1.0, marker='.', label='[10, 50]')
plt.scatter(groupY[1], groupZ[1], c='cyan', s=1.0, alpha=1.0, marker='.', label='[50, 100]')
plt.scatter(groupY[2], groupZ[2], c='magenta', s=1.0, alpha=1.0, marker='.', label='[100, 1000]')
plt.scatter(groupY[3], groupZ[3], c='orange', s=1.0, alpha=1.0, marker='.', label='[1000, 10000]')
plt.scatter(groupY[4], groupZ[4], c='lime', s=1.0, alpha=1.0, marker='.', label='[10000, 100000]')
plt.scatter(groupY[5], groupZ[5], c='blue', s=1.0, alpha=1.0, marker='.', label='[100000, 1000000]')


plt.axis('scaled')
plt.xlim(ymin, ymax)
plt.ylim(zmin, 700)
plt.xlabel('Y axis [cm]', labelpad=1, fontsize=8)
plt.ylabel('Z axis [cm]', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)#set the size of ticks---

plt.title('Events distribution in Z-Y plane', fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.99), fontsize=6, markerscale=5, ncol=4, prop={'size': 3.2})

#Save the plot as a PNG file
#plt.savefig('simu_ZY.png', bbox_inches='tight')
plt.show()    
#---------------------------------------------------------
# Out:
# # event in [0, 10]          :  181
# # event in [10, 50]         :  8297
# # event in [50, 100]        :  10889
# # event in (100, 1000]      :  51182
# # event in (1000, 10000]    :  20897
# # event in (10000, 100000]  :  1682
# # event in (100000, 1000000]:  62
# Total event nums            :  93190
#
# list length of [0, 10]          :  181
# list length of [10, 50]         :  8297
# list length of (50, 100]        :  10889
# list length of (100, 1000]      :  51182
# list length of (1000, 10000]    :  20897
# list length of (10000, 100000]  :  1682
# list length of (100000, 1000000]:  62
#
# ...

# %% [markdown]
# <br />
# <br />
#
# ### (Simu vs Emul), (Simu vs Bias) plots:

# %%
import matplotlib.pyplot as plt
import numpy as np


#Bias vs Simu==========================================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([0, 1200000], [0, 1200000], color="silver", linewidth=0.3, linestyle='--')

#Drawing of data points------
plt.scatter(simuValues, emulValues, c='blue', s=0.4, alpha=1.0, marker='.', label='[1000, 10000]')

plt.axis('scaled')
plt.xlim(0, 1200000)
plt.ylim(0, 1200000)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Emul counts', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Emul vs Simu', fontsize=8)


#Save the plot as a PNG file
#plt.savefig('emul_vs_simu.png', bbox_inches='tight')
plt.show()    





#Emul vs Simu==========================================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([0, 300000], [0, 300000], color="silver", linewidth=0.3, linestyle='--')

#Drawing of data points------
plt.scatter(simuValues, emulValues, c='blue', s=0.4, alpha=1.0, marker='.', label='[1000, 10000]')

plt.axis('scaled')
plt.xlim(0, 300000)
plt.ylim(0, 300000)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Emul counts', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Emul vs Simu', fontsize=8)


#Save the plot as a PNG file
#plt.savefig('emul_vs_simu.png', bbox_inches='tight')
plt.show()    






#Bias vs Simu (-10, 500)==========================================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([-100000, 1100000], [0, 0], color="silver", linewidth=0.3, linestyle='--')

#Drawing of data points------
plt.scatter(simuValues, biasValues, c='crimson', s=0.4, alpha=1.0, marker='.', label='[1000, 10000]')

#plt.axis('scaled')
#plt.xlim(-100000, 1100000)
plt.ylim(-10, 500)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Bias values', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Bias (-10, 500) vs Simu', fontsize=8)


#Save the plot as a PNG file
#plt.savefig('bias_vs_simu.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <br />
# <br />
#
# ### (Simu vs Bias) (log(x)) & 2D plots:

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.colors import LogNorm





#output statistics======================================================
hist10 = []
hist50 = []
hist100 = []
hist1k = []#store bias values when the photon num is within [100, 1000]
hist10k = []
hist100k = []
hist1000k = []
histAll = biasValues

for i in range(0, len(simuValues)):
    bias = biasValues[i]
    phNum = simuValues[i]
    
    if 0 <= phNum <= 10:
        hist10.append(bias)
    if 10 < phNum <= 50:
        hist50.append(bias)
    if 50 < phNum <= 100:
        hist100.append(bias)
    if 100 < phNum <= 1000:
        hist1k.append(bias)
    if 1000 < phNum <= 10000:
        hist10k.append(bias)
    if 10000 < phNum <= 100000:
        hist100k.append(bias)
    if 100000 < phNum <= 1000000:
        hist1000k.append(bias)
    
print("Num of biasValue inside [0, 10]          : ", len(hist10))
print("Num of biasValue inside (10, 50]         : ", len(hist50))
print("Num of biasValue inside (0, 100]         : ", len(hist100))        
print("Num of biasValue inside (100, 1000]      : ", len(hist1k))
print("Num of biasValue inside (1000, 10000]    : ", len(hist10k))
print("Num of biasValue inside (10000, 100000]  : ", len(hist100k))
print("Num of biasValue inside (100000, 1000000]: ", len(hist1000k))
print("Num of biasValue inside [0, 1000000]     : ", len(histAll))


mean10 = round(np.mean(hist10), 3)#keep 3 decimals
std10 = round(np.std(hist10), 3)
mean50 = round(np.mean(hist50), 3)#keep 3 decimals
std50 = round(np.std(hist50), 3)
mean100 = round(np.mean(hist100), 3)#keep 3 decimals
std100 = round(np.std(hist100), 3)
mean1k = round(np.mean(hist1k), 3)#keep 3 decimals
std1k = round(np.std(hist1k), 3)
mean10k = round(np.mean(hist10k), 3)#keep 3 decimals
std10k = round(np.std(hist10k), 3)
mean100k = round(np.mean(hist100k), 3)#keep 3 decimals
std100k = round(np.std(hist100k), 3)
mean1000k = round(np.mean(hist1000k), 3)#keep 3 decimals
std1000k = round(np.std(hist1000k), 3)
meanAll = round(np.mean(histAll), 3)#keep 3 decimals
stdAll = round(np.std(histAll), 3)

print("\nFor [0, 10]          : mean = ", mean10, ", std = ", std10)
print("For (10, 50]         : mean = ", mean50, ", std = ", std50)
print("For (0, 100]         : mean = ", mean100, ", std = ", std100)
print("For (100, 1000]      : mean = ", mean1k, ", std = ", std1k)
print("For (1000, 10000]    : mean = ", mean10k, ", std = ", std10k)
print("For (10000, 100000]  : mean = ", mean100k, ", std = ", std100k)
print("For (100000, 1000000]: mean = ", mean1000k, ", std = ", std1000k)
print("For [0, 1000000]     : mean = ", meanAll, ", std = ", stdAll)


#Explore the (1k, 10k] region------------------------------------------
print("\n\n\nExplore (1k, 10k] region:")
print("Largest bias value within (1k, 10k]: ", max(hist10k))
indexMax10k = biasValues.index(max(hist10k))
print("phNum of this point: ", simuValues[indexMax10k])
print("Positions of this point: (x, y, z) = (", 
      posX[indexMax10k], ", ", posY[indexMax10k], ", ", posZ[indexMax10k], ")")


print("\nSecond largest bias value within (1k, 10k]: ", sorted(hist10k)[-2])
indexSMax10k = biasValues.index(sorted(hist10k)[-2])
print("phNum of this point: ", simuValues[indexSMax10k])
print("Positions of this point: (x, y, z) = (", 
      posX[indexSMax10k], ", ", posY[indexSMax10k], ", ", posZ[indexSMax10k], ")")


#Start drawing figures------------------------------------    
#Set the limts of x, y and z when drawing---
xmin = -400
xmax = 500
ymin = -500
ymax = 500
zmin = -300
zmax = 600




#----------------------------------------------------------------------












#Bias vs Simu (log) (-10, 2000)===================================================================
print("\n\n\n")
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([-100000, 1100000], [0, 0], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10, 10], [-10, 2000], color="silver", linewidth=0.3, linestyle='--')
plt.plot([50, 50], [-10, 2000], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100, 100], [-10, 2000], color="silver", linewidth=0.3, linestyle='--')
plt.plot([1000, 1000], [-10, 2000], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10000, 10000], [-10, 2000], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100000, 100000], [-10, 2000], color="silver", linewidth=0.3, linestyle='--')

#Drawing of data points------
plt.scatter(simuValues, biasValues, c='crimson', s=0.4, alpha=1.0, marker='.', label='[1000, 10000]')

#plt.axis('scaled')
#plt.xlim(-100000, 1100000)
plt.ylim(-10, 2000)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Bias values', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Bias vs Simu (log, (-10, 500))', fontsize=8)

plt.xscale('log')

#Save the plot as a PNG file
#plt.savefig('bias_vs_simu.png', bbox_inches='tight')
plt.show() 




#Bias vs Simu (log) (-10, 100)=========================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([-100000, 1100000], [0, 0], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10, 10], [-10, 100], color="silver", linewidth=0.3, linestyle='--')
plt.plot([50, 50], [-10, 100], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100, 100], [-10, 100], color="silver", linewidth=0.3, linestyle='--')
plt.plot([1000, 1000], [-10, 100], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10000, 10000], [-10, 100], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100000, 100000], [-10, 100], color="silver", linewidth=0.3, linestyle='--')


#Drawing of data points------
plt.scatter(simuValues, biasValues, c='crimson', s=0.4, alpha=1.0, marker='.', label='[1000, 10000]')

#plt.axis('scaled')
#plt.xlim(-100000, 1100000)
plt.ylim(-10, 100)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Bias values', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Bias vs Simu (log, (-10, 100))', fontsize=8)

plt.xscale('log')

#Save the plot as a PNG file
#plt.savefig('bias_vs_simu.png', bbox_inches='tight')
plt.show() 





#Bias vs Simu (log) (-10, 10)=========================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([-100000, 1100000], [0, 0], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10, 10], [-10, 10], color="silver", linewidth=0.3, linestyle='--')
plt.plot([50, 50], [-10, 10], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100, 100], [-10, 10], color="silver", linewidth=0.3, linestyle='--')
plt.plot([1000, 1000], [-10, 10], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10000, 10000], [-10, 10], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100000, 100000], [-10, 10], color="silver", linewidth=0.3, linestyle='--')



#Drawing of data points------
plt.scatter(simuValues, biasValues, c='crimson', s=0.4, alpha=1.0, marker='.')

#plt.axis('scaled')
#plt.xlim(-100000, 1100000)
plt.ylim(-10, 10)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Bias values', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Bias vs Simu (log, (-10, 10))', fontsize=8)

plt.xscale('log')

#Save the plot as a PNG file
#plt.savefig('bias_vs_simu.png', bbox_inches='tight')
plt.show() 





#Bias vs Simu (Log(x) (-2, 2))=========================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([0, 1000000], [0, 0], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10, 10], [-2, 2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([50, 50], [-2, 2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100, 100], [-10, 10], color="silver", linewidth=0.3, linestyle='--')
plt.plot([1000, 1000], [-2, 2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([10000, 10000], [-2, 2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([100000, 100000], [-2, 2], color="silver", linewidth=0.3, linestyle='--')

plt.plot([0, 1000000], [-1, -1], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 1000000], [1, 1], color="silver", linewidth=0.3, linestyle='--')


#Drawing of data points------
plt.scatter(simuValues, biasValues, c='crimson', s=0.4, alpha=1.0, marker='.', label='[1000, 10000]')

#plt.axis('scaled')
#plt.xlim(0, 600000)
plt.ylim(-2, 2)
plt.xlabel('Simu counts', labelpad=1, fontsize=6)
plt.ylabel('Bias values', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.xscale('log')

plt.title('Bias vs Simu (log, (-2, 2))', fontsize=8)


#Save the plot as a PNG file
#plt.savefig('bias_vs_simu.png', bbox_inches='tight')
plt.show() 








#Bias vs log(Simu), (-1, 1), 2D histograms============================
plt.figure(figsize=(4,3),dpi=400)

#Only keep data with -1<=bias<=1
biasPN1 = []
logSimu = []
for label in range(0, len(biasValues)):
    if -1 <= biasValues[label] <= 1:
        biasPN1.append(biasValues[label])
        logSimu.append(math.log10(simuValues[label]))

print("Size of baisPN1: ", len(biasPN1))    
print("Size of logSImu: ", len(logSimu))


plt.xlim(2, 6)
plt.ylim(-1, 1)


#y=x---
plt.plot([0, 6], [0, 0], color="silver", linewidth=0.3, linestyle='--')

plt.plot([3, 3], [-2, 2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([4, 4], [-2, 2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([5, 5], [-2, 2], color="silver", linewidth=0.3, linestyle='--')

plt.plot([0, 6], [-0.1, -0.1], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 6], [0.1, 0.1], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 6], [-0.2, -0.2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 6], [0.2, 0.2], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 6], [-0.5, -0.5], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 6], [0.5, 0.5], color="silver", linewidth=0.3, linestyle='--')



#plt.hist2d(logSimu, biasPN1, bins=(80, 80), cmap='plasma')
plt.hist2d(logSimu, biasPN1, bins=(100, 100), norm=LogNorm(), cmap='plasma')
colorbar = plt.colorbar()



plt.xlabel(r'$\log_{10}(SimuCounts)$', labelpad=1, fontsize=6)
plt.ylabel('Bias values', labelpad=1, fontsize=6)
plt.tick_params(labelsize=5)#set the size of ticks---

plt.title('Bias vs Log(Simu) (-1, 1)', fontsize=8)


#Save the plot as a PNG file
#plt.savefig('bias_vs_simu.png', bbox_inches='tight')
plt.show()
# Out:
# Num of biasValue inside [0, 10]          :  181
# Num of biasValue inside (10, 50]         :  8297
# Num of biasValue inside (0, 100]         :  10889
# Num of biasValue inside (100, 1000]      :  51182
# Num of biasValue inside (1000, 10000]    :  20897
# Num of biasValue inside (10000, 100000]  :  1682
# Num of biasValue inside (100000, 1000000]:  62
# Num of biasValue inside [0, 1000000]     :  93190
#
# For [0, 10]          : mean =  inf , std =  nan
# For (10, 50]         : mean =  0.052 , std =  1.812
# For (0, 100]         : mean =  0.015 , std =  0.253
# For (100, 1000]      : mean =  0.011 , std =  0.14
# For (1000, 10000]    : mean =  0.007 , std =  0.107
# For (10000, 100000]  : mean =  -0.013 , std =  0.076
# For (100000, 1000000]: mean =  -0.063 , std =  0.115
# For [0, 1000000]     : mean =  inf , std =  nan
#
#
#
# Explore (1k, 10k] region:
# Largest bias value within (1k, 10k]:  4.357276
# phNum of this point:  4733.0
# ...

# %% [markdown]
# <br />
# <br />
#
# ### Active region and inactive region:

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.colors import LogNorm



#output statistics======================================================
inPx = [] #up region inside field cage---
inNx = []
outPz = []
outNz = []
outPy = []
outNy = []
outPx = []
outNx = []

inPx_NP1 = [] #up region inside field cage & -1<=bias<=1---
inNx_NP1 = []
outPz_NP1 = []
outNz_NP1 = []
outPy_NP1 = []
outNy_NP1 = []
outPx_NP1 = []
outNx_NP1 = []

inPx_NP010 = [] #up region inside field cage & -0.1<=bias<=0.1---
inNx_NP010 = []
outPz_NP010 = []
outNz_NP010 = []
outPy_NP010 = []
outNy_NP010 = []
outPx_NP010 = []
outNx_NP010 = []


whole = biasValues #The initial total biasValue list---
whole_NP1 = []
whole_NP010 = []
for value in whole:
    if -1 <= value <= 1:
        whole_NP1.append(value)
    if -0.1 <= value <= 0.1:
        whole_NP010.append(value)
        

for i in range(0, len(simuValues)):
    x = posX[i]
    y = posY[i]
    z = posZ[i]
    bias = biasValues[i]

    #Boundaries of field cage: -340<x<340, -350<y<350, -15<z<315
    #Position of  top and bottom CRP: z=+-342
    if 0<x<337 and -347<y<347 and -12<z<312:    
        inPx.append(bias)
        
        if -1.0 <= bias <= 1.0:
            inPx_NP1.append(bias)
        if -0.1 <= bias <= 0.1:
            inPx_NP010.append(bias)
            
    elif -337<x<0 and -347<y<347 and -12<z<312:
        inNx.append(bias)
        
        if -1.0 <= bias <= 1.0:
            inNx_NP1.append(bias)
        if -0.1 <= bias <= 0.1:
            inNx_NP010.append(bias)        
            
    elif z>318:
        outPz.append(bias)
        
        if -1.0 <= bias <= 1.0:
            outPz_NP1.append(bias)
        if -0.1 <= bias <= 0.1:
            outPz_NP010.append(bias)
            
    elif z<-18:
        outNz.append(bias)
        
        if -1.0 <= bias <= 1.0:
            outNz_NP1.append(bias)   
        if -0.1 <= bias <= 0.1:
            outNz_NP010.append(bias)  
        
    elif 353<y and -15<z<315:
        outPy.append(bias)
        
        if -1.0 <= bias <= 1.0:
            outPy_NP1.append(bias) 
        if -0.1 <= bias <= 0.1:
            outPy_NP010.append(bias)
        
    elif y<-353 and -15<z<315:
        outNy.append(bias)
        
        if -1.0 <= bias <= 1.0:
            outNy_NP1.append(bias) 
        if -0.1 <= bias <= 0.1:
            outNy_NP010.append(bias)
        
    elif 343<x and -350<y<350 and -15<z<315:
        outPx.append(bias)
        
        if -1.0 <= bias <= 1.0:
            outPx_NP1.append(bias) 
        if -0.1 <= bias <= 1.0:
            outPx_NP010.append(bias)
            
    elif x<-343 and -350<y<350 and -15<z<315:
        outNx.append(bias)
        
        if -1.0 <= bias <= 1.0:
            outNx_NP1.append(bias) 
        if -0.1 <= bias <= 0.1:
            outNx_NP010.append(bias) 
            
   

inTotal = inPx + inNx
outTotal = outPz + outNz + outPy + outNy + outPx + outNx

inTotal_NP1 = inPx_NP1 + inNx_NP1
inTotal_NP010 = inPx_NP010 + inNx_NP010

            
            
print("Whole space               : ", len(whole))
print("Whole space & -1=<bias=<+1: ", len(whole_NP1),
     "({:.2f}%)".format(len(whole_NP1)/len(whole)*100))
print("Whole s & -0.1=<bias=<+0.1: ", len(whole_NP010),
     "({:.2f}%)".format(len(whole_NP010)/len(whole)*100))

print("\nTotal active  volume      : ", len(inTotal))
print("Whole space & -1=<bias=<+1: ", len(inTotal_NP1),
     "({:.2f}%)".format(len(inTotal_NP1)/len(inTotal)*100))
print("Total a & -0.1=<bias=<+0.1: ", len(inTotal_NP010),
     "({:.2f}%)".format(len(inTotal_NP010)/len(inTotal)*100))

print("\nUp active volume          : ", len(inPx))
print("Up active & -1=<bias=<+1  : ", len(inPx_NP1),
     "({:.2f}%)".format(len(inPx_NP1)/len(inPx)*100))
print("Up ac & -0.1=<bias=<+0.1  : ", len(inPx_NP010),
     "({:.2f}%)".format(len(inPx_NP010)/len(inPx)*100))

print("\nDown active volume        : ", len(inNx))
print("Down active & -1=<bias=<+1: ", len(inNx_NP1),
     "({:.2f}%)".format(len(inNx_NP1)/len(inNx)*100))
print("Down ac & -0.1=<bias=<+0.1: ", len(inNx_NP010),
     "({:.2f}%)".format(len(inNx_NP010)/len(inNx)*100))

print("\nOut posZ volume           : ", len(outPz))
print("Out posZ & -1=<bias=<+1   : ", len(outPz_NP1),
     "({:.2f}%)".format(len(outPz_NP1)/len(outPz)*100))
print("Out  & -0.1=<bias=<+0.1   : ", len(outPz_NP010),
     "({:.2f}%)".format(len(outPz_NP010)/len(outPz)*100))

print("\nOut negZ volume           : ", len(outNz))
print("Out negZ & -1=<bias=<+1   : ", len(outNz_NP1),
     "({:.2f}%)".format(len(outNz_NP1)/len(outNz)*100))
print("Out  & -0.1=<bias=<+0.1   : ", len(outNz_NP010),
     "({:.2f}%)".format(len(outNz_NP010)/len(outNz)*100))

print("\nOut posY volume           : ", len(outPy))
print("Out posY & -1=<bias=<+1   : ", len(outPy_NP1),
     "({:.2f}%)".format(len(outPy_NP1)/len(outPy)*100))
print("Out  & -0.1=<bias=<+0.1   : ", len(outPy_NP010),
     "({:.2f}%)".format(len(outPy_NP010)/len(outPy)*100))

print("\nOut negY volume           : ", len(outNy))
print("Out posY & -1=<bias=<+1   : ", len(outNy_NP1),
     "({:.2f}%)".format(len(outNy_NP1)/len(outNy)*100))
print("Out  & -0.1=<bias=<+0.1   : ", len(outNy_NP010),
     "({:.2f}%)".format(len(outNy_NP010)/len(outNy)*100))

print("\nOut posX volume           : ", len(outPx))
print("Out posX & -1=<bias=<+1   : ", len(outPx_NP1),
     "({:.2f}%)".format(len(outPx_NP1)/len(outPx)*100))
print("Out  & -0.1=<bias=<+0.1   : ", len(outPx_NP010),
     "({:.2f}%)".format(len(outPx_NP010)/len(outPx)*100))

print("\nOut negX volume           : ", len(outNx))
print("Out negX & -1=<bias=<+1   : ", len(outNx_NP1),
     "({:.2f}%)".format(len(outNx_NP1)/len(outNx)*100))
print("Out  & -0.1=<bias=<+0.1   : ", len(outNx_NP010),
     "({:.2f}%)".format(len(outNx_NP010)/len(outNx)*100))


            
            


            
#Drawing-----------------------                  
plt.figure(figsize=(4,3),dpi=400)            
         
#Pay attention: here only bias values inside [-1, 1] are considered---  
print("\n\nPay attention: Here only bias values inside [-1, 1] are considered")


mean_inPx = round(np.mean(inPx_NP1), 3)   
std_inPx = round(np.std(inPx_NP1), 3)
plt.hist(inPx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='red', linewidth=0.7, 
         label='inPx  : $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_inPx,std_inPx))
        
mean_inNx = round(np.mean(inNx_NP1), 3)   
std_inNx = round(np.std(inNx_NP1), 3)
plt.hist(inNx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='blue', linewidth=0.7, 
         label='inNx : $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_inNx,std_inNx)) 

mean_outPz = round(np.mean(outPz_NP1), 3)   
std_outPz = round(np.std(outPz_NP1), 3)
plt.hist(outPz_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='green', linewidth=0.7, 
         label='outPz: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outPz,std_outPz))
        
mean_outNz = round(np.mean(outNz_NP1), 3)   
std_outNz = round(np.std(outNz_NP1), 3)
plt.hist(outNz_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='cyan', linewidth=0.7, 
         label='outNz: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outNz,std_outNz))
                
mean_outPy = round(np.mean(outPy_NP1), 3)   
std_outPy = round(np.std(outPy_NP1), 3)
plt.hist(outPy_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='magenta', linewidth=0.7, 
         label='outPy: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outPy,std_outPy))
        
mean_outNy = round(np.mean(outNy_NP1), 3)   
std_outNy = round(np.std(outNy_NP1), 3)
plt.hist(outNy_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='gold', linewidth=0.7, 
         label='outNy: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outNy,std_outNy))
                        
        
mean_outPx = round(np.mean(outPx_NP1), 3)   
std_outPx = round(np.std(outPx_NP1), 3)
plt.hist(outPx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='lawngreen', linewidth=0.7, 
         label='outPx: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outPx,std_outPx))
        
mean_outNx = round(np.mean(outNx_NP1), 3)   
std_outNx = round(np.std(outNx_NP1), 3)
plt.hist(outNx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='navy', linewidth=0.7, 
         label='outNx: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outNx,std_outNx))
                        
        
        
                
        
plt.xlabel(r'Bias ($\frac{Emul-Simu}{Simu}$)', labelpad=5, fontsize=7)
plt.ylabel('Events', labelpad=1, fontsize=7)
#plt.title('Bias Distribution inside Active Volume', fontsize=8)

plt.grid(color='gray', linestyle='--', linewidth=0.4, zorder=0)
plt.tick_params(labelsize=7)#set the size of ticks---

plt.legend(loc='upper left', bbox_to_anchor=(0.58, 0.99), fontsize=8, markerscale=8, ncol=1, prop={'size': 5})
plt.show()



        


            
#Another performances========================================          

#Drawing-----------------------                  
plt.figure(figsize=(4,3),dpi=400)            

mean_whole = round(np.mean(whole_NP1), 3)   
std_whole = round(np.std(whole_NP1), 3)
plt.hist(whole_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='black', linewidth=0.7, 
         label='Whole: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_whole,std_whole))

mean_inTotal = round(np.mean(inTotal_NP1), 3)   
std_inTotal = round(np.std(inTotal_NP1), 3)
plt.hist(inTotal_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='royalblue', linewidth=0.7, 
         label='Active: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_inTotal,std_inTotal))

mean_inPx = round(np.mean(inPx_NP1), 3)   
std_inPx = round(np.std(inPx_NP1), 3)
plt.hist(inPx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='red', linewidth=0.7, 
         label='inPx  : $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_inPx,std_inPx))
        
mean_inNx = round(np.mean(inNx_NP1), 3)   
std_inNx = round(np.std(inNx_NP1), 3)
plt.hist(inNx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
         edgecolor='blue', linewidth=0.7, 
         label='inNx : $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_inNx,std_inNx)) 

mean_outPz = round(np.mean(outPz_NP1), 3)   
std_outPz = round(np.std(outPz_NP1), 3)
#plt.hist(outPz_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
#         edgecolor='green', linewidth=0.7, 
#         label='outPz: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outPz,std_outPz))
        
mean_outNz = round(np.mean(outNz_NP1), 3)   
std_outNz = round(np.std(outNz_NP1), 3)
#plt.hist(outNz_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
#         edgecolor='cyan', linewidth=0.7, 
#         label='outNz: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outNz,std_outNz))
                
mean_outPy = round(np.mean(outPy_NP1), 3)   
std_outPy = round(np.std(outPy_NP1), 3)
#plt.hist(outPy_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
#         edgecolor='magenta', linewidth=0.7, 
#         label='outPy: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outPy,std_outPy))
        
mean_outNy = round(np.mean(outNy_NP1), 3)   
std_outNy = round(np.std(outNy_NP1), 3)
#plt.hist(outNy_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
#         edgecolor='gold', linewidth=0.7, 
#         label='outNy: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outNy,std_outNy))
                        
        
mean_outPx = round(np.mean(outPx_NP1), 3)   
std_outPx = round(np.std(outPx_NP1), 3)
#plt.hist(outPx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
#         edgecolor='lawngreen', linewidth=0.7, 
#         label='outPx: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outPx,std_outPx))
        
mean_outNx = round(np.mean(outNx_NP1), 3)   
std_outNx = round(np.std(outNx_NP1), 3)
#plt.hist(outNx_NP1, bins=200, range=(-1, 1), color='black', alpha=0.9, histtype='step', 
#         edgecolor='navy', linewidth=0.7, 
#         label='outNx: $\mu$ = {:.3f}, $\sigma$ = {:.3f}'.format(mean_outNx,std_outNx))
                        
        
        
                
        
plt.xlabel(r'Bias ($\frac{Emul-Simu}{Simu}$)', labelpad=5, fontsize=7)
plt.ylabel('Events', labelpad=1, fontsize=7)
#plt.title('Bias Distribution inside Active Volume', fontsize=8)

plt.grid(color='gray', linestyle='--', linewidth=0.4, zorder=0)
plt.tick_params(labelsize=7)#set the size of ticks---

plt.legend(loc='upper left', bbox_to_anchor=(0.57, 0.99), fontsize=8, markerscale=8, ncol=1, prop={'size': 5})
plt.show()
# Out:
# Whole space               :  93190
# Whole space & -1=<bias=<+1:  92919 (99.71%)
# Whole s & -0.1=<bias=<+0.1:  59955 (64.34%)
#
# Total active  volume      :  26230
# Whole space & -1=<bias=<+1:  26208 (99.92%)
# Total a & -0.1=<bias=<+0.1:  21500 (81.97%)
#
# Up active volume          :  12982
# Up active & -1=<bias=<+1  :  12971 (99.92%)
# Up ac & -0.1=<bias=<+0.1  :  10806 (83.24%)
#
# Down active volume        :  13248
# Down active & -1=<bias=<+1:  13237 (99.92%)
# Down ac & -0.1=<bias=<+0.1:  10694 (80.72%)
#
# Out posZ volume           :  28270
# Out posZ & -1=<bias=<+1   :  28230 (99.86%)
# Out  & -0.1=<bias=<+0.1   :  15407 (54.50%)
#
# Out negZ volume           :  28106
# Out negZ & -1=<bias=<+1   :  28073 (99.88%)
# Out  & -0.1=<bias=<+0.1   :  18047 (64.21%)
#
# Out posY volume           :  3204
# Out posY & -1=<bias=<+1   :  3114 (97.19%)
# Out  & -0.1=<bias=<+0.1   :  845 (26.37%)
#
# Out negY volume           :  3111
# Out posY & -1=<bias=<+1   :  3075 (98.84%)
# ...

# %% [markdown]
# <br />
# <br />
#
# ### Bias Distribution in Geometrical Space:

# %%
import matplotlib.pyplot as plt
import numpy as np

range001 = 0 #-0.1<=bias<=0.1
range002 = 0 #0.1<|bias|<=0.2
range005 = 0 #0.2<|bias|<=0.5
range010 = 0 #0.5<|bias|<=1.0
rangeTen = 0 #1.0<|bias|<=10.
rangeInf = 0 #10.<|bias|

rows = 2
list001 = [[] for _ in range(rows)]#2D list, list001[0] is label; list001[1] is bias
list002 = [[] for _ in range(rows)]
list005 = [[] for _ in range(rows)]
list010 = [[] for _ in range(rows)]
listTen = [[] for _ in range(rows)]
listInf = [[] for _ in range(rows)]# value out of 10

for i in range(0, len(biasValues)):
    bias = biasValues[i]
    
    if -0.1 <= bias <= 0.1:
        range001 += 1
        list001[0].append(i)
        list001[1].append(bias)
    elif 0.1 < abs(bias) <= 0.2:
        range002 += 1
        list002[0].append(i)
        list002[1].append(bias)
    elif 0.2 < abs(bias) <= 0.5:
        range005 += 1
        list005[0].append(i)
        list005[1].append(bias)
    elif 0.5 < abs(bias) <= 1.0:
        range010 += 1
        list010[0].append(i)
        list010[1].append(bias)
    elif 1.0 < abs(bias) <= 10.0:
        rangeTen += 1
        listTen[0].append(i)
        listTen[1].append(bias)
    elif 10.0 < abs(bias):
        rangeInf += 1
        listInf[0].append(i)
        listInf[1].append(bias)
        
print("Maximu value of bias: ", max(biasValues))        
print("\n# event in [0.0, 0.1]: ", range001)
print("# event in (0.1, 0.2]: ", range002)
print("# event in (0.2, 0.5]: ", range005)
print("# event in (0.5, 1.0]: ", range010)
print("# event in (1.0, 10.]: ", rangeTen)
print("# event in (10., Inf): ", rangeInf)
totalNum_bias = range001 + range002 + range005 + range010 + rangeTen + rangeInf
print("Total event nums     : ", totalNum_bias)




#Divide posX, posY and posZ into different (6) groups---
rows = 6
groupX = [[] for _ in range(rows)]
groupY = [[] for _ in range(rows)]
groupZ = [[] for _ in range(rows)]

groupX[0] = [posX[i] for i in list001[0]]#corresponding to list001
groupX[1] = [posX[i] for i in list002[0]]#corresponding to list002
groupX[2] = [posX[i] for i in list005[0]]
groupX[3] = [posX[i] for i in list010[0]]
groupX[4] = [posX[i] for i in listTen[0]]
groupX[5] = [posX[i] for i in listInf[0]]

groupY[0] = [posY[i] for i in list001[0]]
groupY[1] = [posY[i] for i in list002[0]]
groupY[2] = [posY[i] for i in list005[0]]
groupY[3] = [posY[i] for i in list010[0]]
groupY[4] = [posY[i] for i in listTen[0]]
groupY[5] = [posY[i] for i in listInf[0]]

groupZ[0] = [posZ[i] for i in list001[0]]
groupZ[1] = [posZ[i] for i in list002[0]]
groupZ[2] = [posZ[i] for i in list005[0]]
groupZ[3] = [posZ[i] for i in list010[0]]
groupZ[4] = [posZ[i] for i in listTen[0]]
groupZ[5] = [posZ[i] for i in listInf[0]]

print("\n")
for i in range(0, 6):
    print("length of groupX[",i,"]: ", len(groupX[i]))
    print("length of groupY[",i,"]: ", len(groupY[i]))
    print("length of groupZ[",i,"]: ", len(groupZ[i]))
#-----------------------------------------------------------
    
    
    
    
    
    
    
    
#Start drawing figures======================================    
#Set the limts of x, y and z when drawing---
xmin = -400
xmax = 500
ymin = -500
ymax = 500
zmin = -300
zmax = 600

#X-Y plane ploting----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

# Define the field cage frame, start from top right, anti-clockwise---
cageXY_y = [350, -350, -350, 350, 350]
cageXY_x = [340, 340, -340, -340, 340]
plt.plot(cageXY_y, cageXY_x, color="grey", linewidth=0.5, linestyle='--')

#Draw the membrane XArapucas---
plt.plot([418, 418], [272, 332], color="grey", linewidth=0.5, linestyle='-')
plt.plot([-418, -418], [272, 332], color="grey", linewidth=0.5, linestyle='-')
plt.plot([418, 418], [256, 196], color="grey", linewidth=0.5, linestyle='-')
plt.plot([-418, -418], [256, 196], color="grey", linewidth=0.5, linestyle='-')
plt.plot([418, 418], [-177, -237], color="grey", linewidth=0.5, linestyle='-')
plt.plot([-418, -418], [-177, -237], color="grey", linewidth=0.5, linestyle='-')
plt.plot([418, 418], [-253, -313], color="grey", linewidth=0.5, linestyle='-')
plt.plot([-418, -418], [-253, -313], color="grey", linewidth=0.5, linestyle='-')

#Set equal scaling for both axes---
plt.axis('scaled')
plt.xlim(ymin, ymax)#Since in x-y plane, x axis is y of the geometry---
plt.ylim(xmin, xmax)

#auxiliary line, along y(geo) and x axis---
yauxi1 = [ymin, ymax]
yauxi2 = [0, 0]
plt.plot(yauxi1, yauxi2, color="silver", linewidth=0.5, linestyle='--')
xauxi1 = [0, 0]
xauxi2 = [xmin, xmax]
plt.plot(xauxi1, xauxi2, color="silver", linewidth=0.5, linestyle='--')

#Drawing of data points------
#plt.scatter(groupY[0], groupX[0], c='lightcyan', s=1.5, alpha=1.0, marker='.', label='0<|bias|<0.1')
#plt.scatter(groupY[1], groupX[1], c='lightblue', s=1.5, alpha=1.0, marker='.', label='0.1<|bias|<0.2')
#plt.scatter(groupY[2], groupX[2], c='orange', s=1.5, alpha=1.0, marker='.', label='0.2<|bias|<0.5')
plt.scatter(groupY[3], groupX[3], c='lawngreen', s=1.5, alpha=1.0, marker='.', label='0.5<|bias|<1.0')
plt.scatter(groupY[4], groupX[4], c='crimson', s=1.5, alpha=1.0, marker='.', label='1.0<|bias|<10.0')
plt.scatter(groupY[5], groupX[5], c='blue', s=1.5, alpha=1.0, marker='.', label='10.0<|bias|')

plt.xlabel('Y axis [cm]', labelpad=1, fontsize=8)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=8)
plt.title('BiasValue distribution in X-Y plane', fontsize=10)
plt.tick_params(labelsize=7)#set the size of ticks---
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.98), fontsize=6, markerscale=5, ncol=3, prop={'size': 4})

#Save the plot as a PNG file
#plt.savefig('bias_XY.png', bbox_inches='tight')
plt.show()    
#---------------------------------------------------------
    
    
    

    
#X-Z plane ploting----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#Define the field cage frame, start from top right, anti-clockwise---
cageXZ_z = [315, -15, -15, 315, 315]
cageXZ_x = [340, 340, -340, -340, 340]
plt.plot(cageXZ_z, cageXZ_x, color="grey", linewidth=0.5, linestyle='--')

#auxiliary line, along y(geo) and x axis---
yauxi3 = [zmin, zmax]
yauxi4 = [0, 0]
plt.plot(yauxi3, yauxi4, color="silver", linewidth=0.5, linestyle='--')
xauxi3 = [0, 0]
xauxi4 = [xmin, xmax]
plt.plot(xauxi3, xauxi4, color="silver", linewidth=0.5, linestyle='--')

#Draw the membrane XArapucas---
op00z = [180, 120, 120, 180, 180]#From top right, anti-clockwise---
op00x = [332, 332, 272, 272, 332]
plt.plot(op00z, op00x, color="grey", linewidth=0.5, linestyle='-')
op02z = op00z
op02x = [256, 256, 196, 196, 256]
plt.plot(op02z, op02x, color="grey", linewidth=0.5, linestyle='-')
op16z = op00z
op16x = [-177, -177, -237, -237, -177]
plt.plot(op16z, op16x, color="grey", linewidth=0.5, linestyle='-')
op22z = op00z
op22x = [-253, -253, -313, -313, -253]
plt.plot(op22z, op22x, color="grey", linewidth=0.5, linestyle='-')


#Drawing of data points------
#plt.scatter(groupZ[0], groupX[0], c='lightcyan', s=1.5, alpha=1.0, marker='.', label='0<|bias|<0.1')
#plt.scatter(groupZ[1], groupX[1], c='lightblue', s=1.5, alpha=1.0, marker='.', label='0.1<|bias|<0.2')
#plt.scatter(groupZ[2], groupX[2], c='orange', s=1.5, alpha=1.0, marker='.', label='0.2<|bias|<0.5')
plt.scatter(groupZ[3], groupX[3], c='lawngreen', s=1.5, alpha=1.0, marker='.', label='0.5<|bias|<1.0')
plt.scatter(groupZ[4], groupX[4], c='crimson', s=1.5, alpha=1.0, marker='.', label='1.0<|bias|<10.0')
plt.scatter(groupZ[5], groupX[5], c='blue', s=1.5, alpha=1.0, marker='.', label='10.0<|bias|')


plt.axis('scaled')
plt.xlim(zmin, zmax)
plt.ylim(xmin, xmax)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=8)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)#set the size of ticks---

plt.title('BiasValue distribution in X-Z plane', fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.98), fontsize=6, markerscale=5, ncol=3, prop={'size': 4})

#Save the plot as a PNG file
#plt.savefig('bias_XZ.png', bbox_inches='tight')
plt.show()    
#---------------------------------------------------------
    
        
        
    
    
#Z-Y plane ploting----------------------------------------
plt.figure(figsize=(4,3),dpi=400)


#Define the field cage frame, start from top right, anti-clockwise---
cageZY_y = [350, -350, -350, 350, 350]
cageZY_z = [315, 315, -15, -15, 315]
plt.plot(cageZY_y, cageZY_z, color="grey", linewidth=0.5, linestyle='--')

#auxiliary line, along y(geo) axis---
yauxi5 = [ymin, ymax]
yauxi6 = [0, 0]
plt.plot(yauxi5, yauxi6, color="silver", linewidth=0.5, linestyle='--')
xauxi5= [0, 0]
xauxi6 = [zmin, 700]
plt.plot(xauxi5, xauxi6, color="silver", linewidth=0.5, linestyle='--')

#Draw the membrane XArapucas---
plt.plot([418, 418], [120, 180], color="grey", linewidth=0.5, linestyle='-')#opch0, 2, 16, 22---
plt.plot([-418, -418], [120, 180], color="grey", linewidth=0.5, linestyle='-')#opch1, 3, 17, 23---
op04y = [236, 176, 176, 236, 236]#From top right, anti-clockwise---
op04z = [288, 288, 228, 228, 288]
plt.plot(op04y, op04z, color="grey", linewidth=0.5, linestyle='-')
op05y = [-101, -161, -161, -101, -101]#From top right, anti-clockwise---
op05z = [288, 288, 228, 228, 288]
plt.plot(op05y, op05z, color="grey", linewidth=0.5, linestyle='-')
op06y = [69, 9, 9, 69, 69]#From top right, anti-clockwise---
op06z = [217, 217, 157, 157, 217]
plt.plot(op06y, op06z, color="grey", linewidth=0.5, linestyle='-')
op07y = [-270, -330, -330, -270, -270]#From top right, anti-clockwise---
op07z = [217, 217, 157, 157, 217]
plt.plot(op07y, op07z, color="grey", linewidth=0.5, linestyle='-')
op08y = op04y#From top right, anti-clockwise---
op08z = [142, 142, 82, 82, 142]
plt.plot(op08y, op08z, color="grey", linewidth=0.5, linestyle='-')
op09y = [-9, -69, -69, -9, -9]#From top right, anti-clockwise---
op09z = [142, 142, 82, 82, 142]
plt.plot(op09y, op09z, color="grey", linewidth=0.5, linestyle='-')
op10y = [161, 101, 101, 161, 161]#From top right, anti-clockwise---
op10z = [71, 71, 11, 11, 71]
plt.plot(op10y, op10z, color="grey", linewidth=0.5, linestyle='-')
op11y = [-176, -236, -236, -176, -176]#From top right, anti-clockwise---
op11z = [71, 71, 11, 11, 71]
plt.plot(op11y, op11z, color="grey", linewidth=0.5, linestyle='-')

#Drawing of data points------
#plt.scatter(groupY[0], groupZ[0], c='lightcyan', s=2, alpha=1.0, marker='.', label='0<|bias|<0.1')
#plt.scatter(groupY[1], groupZ[1], c='lightblue', s=2, alpha=1.0, marker='.', label='0.1<|bias|<0.2')
#plt.scatter(groupY[2], groupZ[2], c='orange', s=2, alpha=1.0, marker='.', label='0.2<|bias|<0.5')
plt.scatter(groupY[3], groupZ[3], c='lawngreen', s=2, alpha=1.0, marker='.', label='0.5<|bias|<1.0')
plt.scatter(groupY[4], groupZ[4], c='crimson', s=2, alpha=1.0, marker='.', label='1.0<|bias|<10.0')
plt.scatter(groupY[5], groupZ[5], c='blue', s=2, alpha=1.0, marker='.', label='10.0<|bias|')

plt.axis('scaled')
plt.xlim(ymin, ymax)
plt.ylim(zmin, 700)
plt.xlabel('Y axis [cm]', labelpad=1, fontsize=8)
plt.ylabel('Z axis [cm]', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)#set the size of ticks---

plt.title('BiasValue distribution in Z-Y plane', fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.99), fontsize=6, markerscale=5, ncol=3, prop={'size': 4})

#Save the plot as a PNG file
#plt.savefig('bias_ZY.png', bbox_inches='tight')
plt.show()    
#---------------------------------------------------------
# Out:
# Maximu value of bias:  inf
#
# # event in [0.0, 0.1]:  59955
# # event in (0.1, 0.2]:  20191
# # event in (0.2, 0.5]:  11498
# # event in (0.5, 1.0]:  1275
# # event in (1.0, 10.]:  235
# # event in (10., Inf):  36
# Total event nums     :  93190
#
#
# length of groupX[ 0 ]:  59955
# length of groupY[ 0 ]:  59955
# length of groupZ[ 0 ]:  59955
# length of groupX[ 1 ]:  20191
# length of groupY[ 1 ]:  20191
# length of groupZ[ 1 ]:  20191
# length of groupX[ 2 ]:  11498
# length of groupY[ 2 ]:  11498
# length of groupZ[ 2 ]:  11498
# length of groupX[ 3 ]:  1275
# length of groupY[ 3 ]:  1275
# length of groupZ[ 3 ]:  1275
# length of groupX[ 4 ]:  235
# length of groupY[ 4 ]:  235
# length of groupZ[ 4 ]:  235
# length of groupX[ 5 ]:  36
# length of groupY[ 5 ]:  36
# length of groupZ[ 5 ]:  36
